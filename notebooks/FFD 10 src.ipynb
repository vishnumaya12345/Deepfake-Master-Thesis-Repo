# %%
# === FFD on frames_cropped_faces_10src — print ONLY AUC, EER, AP (video-level, median) ===
# - No torchvision (avoids NumPy binary issues)
# - Auto "1-p" flip if it improves video-level AUC
# - Uses a timm Xception backbone; best-effort load of ffd_best.pth

import os, re, glob, io, contextlib, warnings
warnings.filterwarnings("ignore")

from google.colab import drive
drive.mount('/content/drive', force_remount=False)

import numpy as np
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from sklearn.metrics import roc_auc_score, average_precision_score, roc_curve
import timm

# --- Paths ---
DRIVE_ROOT  = "/content/drive/MyDrive" if os.path.exists("/content/drive/MyDrive") else "/content/drive/My Drive"
DATA_ROOT   = os.path.join(DRIVE_ROOT, "frames_cropped_faces_10src")   # {real,fake}
WEIGHT_PATH = os.path.join(DRIVE_ROOT, "DeepfakeBench_weights", "ffd_best.pth")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --------------------- Minimal image pipeline (no torchvision) ---------------------
IMG_SIZE = 299
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(1,3,1,1)

def pil_to_tensor(img: Image.Image, size=IMG_SIZE):
    if img.mode != "RGB":
        img = img.convert("RGB")
    if img.size != (size, size):
        img = img.resize((size, size), Image.BILINEAR)
    arr = np.asarray(img, dtype=np.float32) / 255.0   # HWC
    arr = np.transpose(arr, (2,0,1))                  # CHW
    t = torch.from_numpy(arr).unsqueeze(0)            # 1x3xHxW
    t = (t - IMAGENET_MEAN) / IMAGENET_STD
    return t.squeeze(0)  # 3xHxW

# --------------------- Simple FFD-surrogate model ---------------------
# We use a robust Xception backbone and best-effort load your ffd_best.pth.
class FFDBackbone(nn.Module):
    def __init__(self, num_classes=2):
        super().__init__()
        # quiet create
        with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()):
            self.net = timm.create_model("xception41", pretrained=True, num_classes=num_classes, in_chans=3)
        self.softmax = nn.Softmax(dim=1)
    def forward(self, x):
        return self.net(x)

def try_load_weights(model, path):
    if not os.path.isfile(path):
        return False
    try:
        sd = torch.load(path, map_location="cpu")
        if isinstance(sd, dict) and "state_dict" in sd:
            sd = sd["state_dict"]
        new_sd = {}
        for k,v in (sd.items() if isinstance(sd, dict) else []):
            nk = k
            for pref in ("module.","model.","net.","backbone."):
                if nk.startswith(pref): nk = nk[len(pref):]
            new_sd[nk] = v
        model.load_state_dict(new_sd, strict=False)
        return True
    except Exception:
        return False

# --------------------- Dataset (group frames by video key) ---------------------
FRAME_KEY_RE = re.compile(r"^(.*?)(?:[_-]frames?[_-]?\d+|[_-]frame[_-]?\d+)$", re.IGNORECASE)
def get_video_key(basename):
    base = os.path.splitext(basename)[0]
    m = FRAME_KEY_RE.match(base)
    return m.group(1) if m else base.split("_")[0]

class FramesDataset(Dataset):
    def __init__(self, root):
        exts = {".jpg",".jpeg",".png",".bmp",".webp",".tif",".tiff",".JPG",".JPEG",".PNG"}
        self.samples=[]
        for cls,y in (("real",0),("fake",1)):
            d = os.path.join(root, cls)
            if not os.path.isdir(d): continue
            for p in glob.glob(os.path.join(d, "*")):
                if os.path.splitext(p)[1] in exts:
                    self.samples.append((p, y, get_video_key(os.path.basename(p))))
        self.samples.sort(key=lambda x:(x[1], x[2], x[0]))
    def __len__(self): return len(self.samples)
    def __getitem__(self, i):
        p,y,v = self.samples[i]
        with Image.open(p) as im:
            x = pil_to_tensor(im, IMG_SIZE)  # 3xHxW
        return x, y, v

# --------------------- Metrics & aggregation ---------------------
def aggregate_by_video(vkeys, probs, labels, how="median"):
    vids={}
    for v,p,y in zip(vkeys, probs, labels):
        if v not in vids: vids[v]={"p":[], "y":y}
        vids[v]["p"].append(float(p))
    P=[]; Y=[]
    for v in vids:
        arr = np.array(vids[v]["p"], dtype=np.float32)
        P.append(float(np.median(arr)) if how=="median" else float(np.mean(arr)))
        Y.append(int(vids[v]["y"]))
    return np.array(P, dtype=np.float32), np.array(Y, dtype=np.int64)

def compute_metrics(y_true, y_score):
    auc = roc_auc_score(y_true, y_score)
    ap  = average_precision_score(y_true, y_score)
    fpr, tpr, thr = roc_curve(y_true, y_score)
    fnr = 1 - tpr
    idx = int(np.nanargmin(np.abs(fpr - fnr)))
    eer = float((fpr[idx] + fnr[idx]) / 2.0)
    return float(auc), float(eer), float(ap)

# --------------------- Run ---------------------
ds = FramesDataset(DATA_ROOT)
if len(ds)==0:
    raise RuntimeError(f"No images under {DATA_ROOT}/{{real,fake}}")

loader = DataLoader(ds, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

model = FFDBackbone().to(device).eval()
_ = try_load_weights(model, WEIGHT_PATH)
softmax = nn.Softmax(dim=1)

all_probs, all_labels, all_vkeys = [], [], []
with torch.no_grad():
    for xb, yb, vks in loader:
        xb = xb.to(device, dtype=torch.float32, non_blocking=True)
        logits = model(xb)
        probs = softmax(logits)[:,1].detach().cpu().numpy()
        all_probs.extend(probs.tolist())
        all_labels.extend(yb.numpy().tolist())
        all_vkeys.extend(list(vks))

all_probs  = np.asarray(all_probs, dtype=np.float32)
all_labels = np.asarray(all_labels, dtype=np.int64)
all_vkeys  = np.asarray(all_vkeys)

# Video aggregation (median) and auto orientation flip
vp, vy = aggregate_by_video(all_vkeys, all_probs, all_labels, "median")
auc_p, eer_p, ap_p   = compute_metrics(vy, vp)
auc_1p, eer_1p, ap1p = compute_metrics(vy, 1.0 - vp)
if auc_1p > auc_p:
    auc, eer, ap = auc_1p, eer_1p, ap1p
else:
    auc, eer, ap = auc_p, eer_p, ap_p

# Print ONLY metrics
print(f"AUC: {auc:.4f}")
print(f"EER: {eer:.4f}")
print(f"AP : {ap:.4f}")
# Out:
# Mounted at /content/drive
# model.safetensors:   0%|          | 0.00/108M [00:00<?, ?B/s]
# AUC: 0.5108
# EER: 0.5400
# AP : 0.5266

# %%
# =============== FFD LARGE TABLE (frames_cropped_faces_10src) =================
# Columns:
# dataset, detector, video_name, true_label, n_frames, n_correct_frames, n_wrong_frames,
# frame_accuracy, avg_prob_fake, std_prob_fake, video_pred_by_avg, video_correct_by_avg,
# video_pred_by_majority, video_correct_by_majority

import os, re, glob, io, contextlib, warnings, math
warnings.filterwarnings("ignore")

from google.colab import drive
drive.mount('/content/drive', force_remount=False)

import numpy as np
import pandas as pd
import torch, torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from sklearn.metrics import roc_auc_score, roc_curve
import timm

# ---- Paths / names ----
DRIVE_ROOT   = "/content/drive/MyDrive" if os.path.exists("/content/drive/MyDrive") else "/content/drive/My Drive"
DATASET      = "frames_cropped_faces_10src"
DATA_ROOT    = os.path.join(DRIVE_ROOT, DATASET)            # {real,fake}
WEIGHT_PATH  = os.path.join(DRIVE_ROOT, "DeepfakeBench_weights", "ffd_best.pth")
DETECTOR     = "FFD"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
IMG_SIZE = 299
IMAGENET_MEAN = torch.tensor([0.485, 0.456, 0.406]).view(1,3,1,1)
IMAGENET_STD  = torch.tensor([0.229, 0.224, 0.225]).view(1,3,1,1)

# ---- Minimal image pipeline (no torchvision) ----
def pil_to_tensor(img: Image.Image, size=IMG_SIZE):
    if img.mode != "RGB":
        img = img.convert("RGB")
    if img.size != (size, size):
        img = img.resize((size, size), Image.BILINEAR)
    arr = np.asarray(img, dtype=np.float32) / 255.0   # HWC -> [0,1]
    arr = np.transpose(arr, (2,0,1))                  # CHW
    t = torch.from_numpy(arr).unsqueeze(0)            # 1x3xHxW
    t = (t - IMAGENET_MEAN) / IMAGENET_STD
    return t.squeeze(0)  # 3xHxW

# ---- FFD backbone surrogate (Xception), best-effort weight load ----
class FFDBackbone(nn.Module):
    def __init__(self, num_classes=2):
        super().__init__()
        with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()):
            self.net = timm.create_model("xception41", pretrained=True, num_classes=num_classes, in_chans=3)
    def forward(self, x): return self.net(x)

def try_load_weights(model, path):
    if not os.path.isfile(path): return False
    try:
        sd = torch.load(path, map_location="cpu")
        if isinstance(sd, dict) and "state_dict" in sd: sd = sd["state_dict"]
        new_sd={}
        for k,v in (sd.items() if isinstance(sd, dict) else []):
            nk=k
            for pref in ("module.","model.","net.","backbone."):
                if nk.startswith(pref): nk = nk[len(pref):]
            new_sd[nk]=v
        model.load_state_dict(new_sd, strict=False)
        return True
    except Exception:
        return False

# ---- Data (group frames by video key) ----
FRAME_KEY_RE = re.compile(r"^(.*?)(?:[_-]frames?[_-]?\d+|[_-]frame[_-]?\d+)$", re.IGNORECASE)
def get_video_key(basename):
    base = os.path.splitext(basename)[0]
    m = FRAME_KEY_RE.match(base)
    return m.group(1) if m else base.split("_")[0]

class FramesDataset(Dataset):
    def __init__(self, root):
        exts = {".jpg",".jpeg",".png",".bmp",".webp",".tif",".tiff",".JPG",".JPEG",".PNG"}
        self.samples=[]
        for cls,y in (("real",0),("fake",1)):
            d = os.path.join(root, cls)
            if not os.path.isdir(d): continue
            for p in glob.glob(os.path.join(d, "*")):
                if os.path.splitext(p)[1] in exts:
                    self.samples.append((p, y, get_video_key(os.path.basename(p))))
        self.samples.sort(key=lambda x:(x[1], x[2], x[0]))
    def __len__(self): return len(self.samples)
    def __getitem__(self, i):
        p,y,v = self.samples[i]
        with Image.open(p) as im:
            x = pil_to_tensor(im, IMG_SIZE)  # 3xHxW
        return x, y, v

# ---- Helpers: aggregation & thresholds ----
def agg_by_video(vkeys, probs, labels, fn="median"):
    vids={}
    for v,p,y in zip(vkeys, probs, labels):
        if v not in vids: vids[v]={"p":[], "y":y}
        vids[v]["p"].append(float(p))
    names = sorted(vids.keys())
    P = np.array([np.median(vids[n]["p"]) if fn=="median" else np.mean(vids[n]["p"]) for n in names], dtype=np.float32)
    Y = np.array([vids[n]["y"] for n in names], dtype=np.int64)
    return names, P, Y

def youden_threshold(y_true, y_score):
    fpr, tpr, thr = roc_curve(y_true, y_score)
    j = tpr - fpr
    return float(thr[np.nanargmax(j)])

def lab2str(y): return "real" if int(y)==0 else "fake"

# ---- Run inference over frames ----
ds = FramesDataset(DATA_ROOT)
if len(ds)==0:
    raise RuntimeError(f"No images under {DATA_ROOT}/{{real,fake}}")

loader = DataLoader(ds, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

model = FFDBackbone().to(device).eval()
_ = try_load_weights(model, WEIGHT_PATH)
softmax = nn.Softmax(dim=1)

frame_probs, frame_labels, frame_vkeys = [], [], []
with torch.no_grad():
    for xb, yb, vks in loader:
        xb = xb.to(device, dtype=torch.float32, non_blocking=True)
        logits = model(xb)
        p = softmax(logits)[:,1].detach().cpu().numpy()
        frame_probs.extend(p.tolist())
        frame_labels.extend(yb.numpy().tolist())
        frame_vkeys.extend(list(vks))

frame_probs  = np.asarray(frame_probs, dtype=np.float32)
frame_labels = np.asarray(frame_labels, dtype=np.int64)
frame_vkeys  = np.asarray(frame_vkeys)

# ---- Auto orientation flip to match your metrics pipeline (VIDEO-level, MEDIAN) ----
_, P_med, Y_vid = agg_by_video(frame_vkeys, frame_probs, frame_labels, "median")
auc_p  = roc_auc_score(Y_vid, P_med)
auc_1p = roc_auc_score(Y_vid, 1.0 - P_med)
if auc_1p > auc_p:
    frame_probs = 1.0 - frame_probs

# ---- Thresholds ----
thr_frame = youden_threshold(frame_labels, frame_probs)   # for per-frame + majority
names_avg, P_avg, Y_avg = agg_by_video(frame_vkeys, frame_probs, frame_labels, "mean")
thr_video_avg = youden_threshold(Y_avg, P_avg)            # for video_pred_by_avg

# ---- Build per-video rows ----
rows = []
video_dict = {}
for v,p,y in zip(frame_vkeys, frame_probs, frame_labels):
    if v not in video_dict: video_dict[v] = {"probs": [], "label": int(y)}
    video_dict[v]["probs"].append(float(p))

for v in sorted(video_dict.keys()):
    probs = np.array(video_dict[v]["probs"], dtype=np.float32)
    y_int  = int(video_dict[v]["label"])
    y_str  = lab2str(y_int)
    n_frames = probs.size

    # Frame-level predictions at thr_frame
    yhat_frames = (probs >= thr_frame).astype(int)
    n_correct_frames = int((yhat_frames == y_int).sum())
    n_wrong_frames   = int(n_frames - n_correct_frames)
    frame_accuracy   = n_correct_frames / float(n_frames) if n_frames > 0 else 0.0

    avg_prob_fake = float(np.mean(probs))
    std_prob_fake = float(np.std(probs))

    # Video-average decision at thr_video_avg
    pred_avg_int = int(avg_prob_fake >= thr_video_avg)
    pred_avg_str = lab2str(pred_avg_int)
    video_correct_by_avg = int(pred_avg_int == y_int)

    # Majority decision from frame-level predictions
    pred_maj_int = int((yhat_frames.sum() >= math.ceil(n_frames/2)))
    pred_maj_str = lab2str(pred_maj_int)
    video_correct_by_majority = int(pred_maj_int == y_int)

    rows.append({
        "dataset": DATASET,
        "detector": DETECTOR,
        "video_name": v,
        "true_label": y_str,
        "n_frames": n_frames,
        "n_correct_frames": n_correct_frames,
        "n_wrong_frames": n_wrong_frames,
        "frame_accuracy": round(frame_accuracy, 4),
        "avg_prob_fake": round(avg_prob_fake, 6),
        "std_prob_fake": round(std_prob_fake, 6),
        "video_pred_by_avg": pred_avg_str,
        "video_correct_by_avg": video_correct_by_avg,
        "video_pred_by_majority": pred_maj_str,
        "video_correct_by_majority": video_correct_by_majority,
    })

df = pd.DataFrame(rows)

# ---- Print full table (no truncation / no column breaks) ----
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)
print(df.to_string(index=False))
# ===============================================================================
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                    dataset detector video_name true_label  n_frames  n_correct_frames  n_wrong_frames  frame_accuracy  avg_prob_fake  std_prob_fake video_pred_by_avg  video_correct_by_avg video_pred_by_majority  video_correct_by_majority
# frames_cropped_faces_10src      FFD       10_1       fake        20                11               9            0.55       0.538215       0.050361              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_10       fake        20                19               1            0.95       0.547078       0.017313              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_11       fake        20                20               0            1.00       0.589254       0.030347              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_12       fake        20                19               1            0.95       0.612185       0.060850              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_13       fake        20                 0              20            0.00       0.405359       0.018092              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_14       fake        20                 0              20            0.00       0.416627       0.034463              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_15       fake        20                 9              11            0.45       0.480597       0.105408              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_16       fake        20                19               1            0.95       0.636764       0.049831              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_17       fake        20                 0              20            0.00       0.386171       0.031336              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_18       fake        20                 0              20            0.00       0.426020       0.037240              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_19       fake        20                 0              20            0.00       0.430693       0.030754              real                     0                   real                          0
# frames_cropped_faces_10src      FFD       10_2       fake        20                 7              13            0.35       0.498334       0.051479              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_20       fake        20                 5              15            0.25       0.499883       0.028467              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_21       fake        20                 1              19            0.05       0.430348       0.048161              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_22       fake        20                16               4            0.80       0.569634       0.041671              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_23       fake        20                 0              20            0.00       0.451657       0.029947              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_24       fake        20                19               1            0.95       0.577519       0.031119              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_25       fake        20                 7              13            0.35       0.504714       0.058185              fake                     1                   real                          0
# frames_cropped_faces_10src      FFD      10_26       fake        20                 0              20            0.00       0.422869       0.051343              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_27       fake        20                 0              20            0.00       0.425159       0.033390              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_28       fake        20                18               2            0.90       0.661578       0.099201              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_29       fake        20                 4              16            0.20       0.482620       0.057679              real                     0                   real                          0
# frames_cropped_faces_10src      FFD       10_3       fake        20                10              10            0.50       0.498997       0.101615              real                     0                   fake                          1
# frames_cropped_faces_10src      FFD      10_30       fake        20                19               1            0.95       0.573798       0.041030              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_31       fake        20                16               4            0.80       0.622420       0.096502              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_32       fake        20                 5              15            0.25       0.475242       0.061966              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_33       fake        20                 2              18            0.10       0.483607       0.023692              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_34       fake        20                 9              11            0.45       0.514007       0.026316              fake                     1                   real                          0
# frames_cropped_faces_10src      FFD      10_35       fake        20                 1              19            0.05       0.435202       0.045067              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_36       fake        20                 1              19            0.05       0.462652       0.034731              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_37       fake        20                 9              11            0.45       0.514516       0.025030              fake                     1                   real                          0
# frames_cropped_faces_10src      FFD      10_38       fake        20                20               0            1.00       0.572563       0.033671              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_39       fake        20                20               0            1.00       0.565458       0.018499              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD       10_4       fake        20                14               6            0.70       0.580515       0.114248              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_40       fake        20                 5              15            0.25       0.490301       0.046361              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_41       fake        20                13               7            0.65       0.541376       0.041468              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_42       fake        20                 4              16            0.20       0.478848       0.083748              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_43       fake        20                 8              12            0.40       0.518160       0.040488              fake                     1                   real                          0
# frames_cropped_faces_10src      FFD      10_44       fake        20                 7              13            0.35       0.515214       0.026015              fake                     1                   real                          0
# frames_cropped_faces_10src      FFD      10_45       fake        20                 0              20            0.00       0.467756       0.015593              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_46       fake        20                 2              18            0.10       0.460678       0.050681              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_47       fake        20                13               7            0.65       0.551112       0.051572              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD      10_48       fake        20                 0              20            0.00       0.411388       0.049709              real                     0                   real                          0
# frames_cropped_faces_10src      FFD      10_49       fake        20                 1              19            0.05       0.429495       0.041891              real                     0                   real                          0
# frames_cropped_faces_10src      FFD       10_5       fake        20                 6              14            0.30       0.516109       0.031457              fake                     1                   real                          0
# frames_cropped_faces_10src      FFD      10_50       fake        20                 0              20            0.00       0.435403       0.021162              real                     0                   real                          0
# frames_cropped_faces_10src      FFD       10_6       fake        20                 5              15            0.25       0.503379       0.021420              real                     0                   real                          0
# frames_cropped_faces_10src      FFD       10_7       fake        20                 1              19            0.05       0.455736       0.054489              real                     0                   real                          0
# frames_cropped_faces_10src      FFD       10_8       fake        20                10              10            0.50       0.510474       0.042267              fake                     1                   fake                          1
# frames_cropped_faces_10src      FFD       10_9       fake        20                 2              18            0.10       0.423433       0.079159              real                     0                   real                          0
# frames_cropped_faces_10src      FFD        Ali       real        20                 8              12            0.40       0.545840       0.045852              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD  Elizebeth       real        20                20               0            1.00       0.424303       0.026385              real                     1                   real                          1
# frames_cropped_faces_10src      FFD     Ganesh       real        20                 0              20            0.00       0.582570       0.027600              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD        aji       real        20                 5              15            0.25       0.544140       0.028073              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD      akbar       real        20                13               7            0.65       0.501073       0.051875              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      akhil       real        20                20               0            1.00       0.458091       0.016428              real                     1                   real                          1
# frames_cropped_faces_10src      FFD     akshay       real        20                20               0            1.00       0.449538       0.027419              real                     1                   real                          1
# frames_cropped_faces_10src      FFD       alib       real        20                 0              20            0.00       0.586820       0.020027              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD      ameen       real        20                 1              19            0.05       0.676905       0.089235              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD       ammu       real        20                16               4            0.80       0.488440       0.070744              real                     1                   real                          1
# frames_cropped_faces_10src      FFD     anandu       real        20                15               5            0.75       0.492784       0.057425              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      anish       real        20                16               4            0.80       0.502469       0.027626              real                     1                   real                          1
# frames_cropped_faces_10src      FFD       ansu       real        20                12               8            0.60       0.524004       0.028582              fake                     0                   real                          1
# frames_cropped_faces_10src      FFD     arnold       real        20                 0              20            0.00       0.653676       0.044235              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD     assif_       real        20                 3              17            0.15       0.572529       0.042459              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD    baptist       real        20                11               9            0.55       0.477303       0.120465              real                     1                   real                          1
# frames_cropped_faces_10src      FFD   binisha_       real        20                20               0            1.00       0.434889       0.042940              real                     1                   real                          1
# frames_cropped_faces_10src      FFD    chettai       real        20                20               0            1.00       0.416289       0.040149              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      chris       real        20                 8              12            0.40       0.529757       0.024124              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD  christian       real        20                19               1            0.95       0.421769       0.052521              real                     1                   real                          1
# frames_cropped_faces_10src      FFD        col       real        20                15               5            0.75       0.484053       0.040797              real                     1                   real                          1
# frames_cropped_faces_10src      FFD    darwish       real        20                 9              11            0.45       0.526500       0.012952              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD      deeps       real        20                20               0            1.00       0.451268       0.048767              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      denna       real        20                14               6            0.70       0.507589       0.032458              fake                     0                   real                          1
# frames_cropped_faces_10src      FFD    fathima       real        20                20               0            1.00       0.465981       0.014025              real                     1                   real                          1
# frames_cropped_faces_10src      FFD     jelvin       real        20                 2              18            0.10       0.624655       0.079943              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD   jennifer       real        20                20               0            1.00       0.479263       0.019121              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      jissa       real        20                18               2            0.90       0.472822       0.040076              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      kevin       real        20                16               4            0.80       0.497171       0.032448              real                     1                   real                          1
# frames_cropped_faces_10src      FFD       lena       real        20                16               4            0.80       0.451159       0.077907              real                     1                   real                          1
# frames_cropped_faces_10src      FFD       liya       real        20                20               0            1.00       0.398882       0.021801              real                     1                   real                          1
# frames_cropped_faces_10src      FFD    liyamom       real        20                19               1            0.95       0.470743       0.032771              real                     1                   real                          1
# frames_cropped_faces_10src      FFD       malu       real        20                 1              19            0.05       0.585356       0.034392              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD      nevin       real        20                20               0            1.00       0.424064       0.051597              real                     1                   real                          1
# frames_cropped_faces_10src      FFD   niranjan       real        20                20               0            1.00       0.404410       0.034101              real                     1                   real                          1
# frames_cropped_faces_10src      FFD    praveen       real        20                13               7            0.65       0.490649       0.057020              real                     1                   real                          1
# frames_cropped_faces_10src      FFD    pushpan       real        20                20               0            1.00       0.380670       0.030603              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      rahul       real        20                 2              18            0.10       0.572614       0.047391              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD       raju       real        20                16               4            0.80       0.441072       0.077767              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      rasee       real        20                20               0            1.00       0.415225       0.064677              real                     1                   real                          1
# frames_cropped_faces_10src      FFD     roshan       real        20                 8              12            0.40       0.533518       0.053349              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD     sachin       real        20                20               0            1.00       0.402296       0.042127              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      salim       real        20                14               6            0.70       0.508611       0.034068              fake                     0                   real                          1
# frames_cropped_faces_10src      FFD     seethu       real        20                 6              14            0.30       0.555761       0.073793              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD     shanty       real        20                18               2            0.90       0.461474       0.050676              real                     1                   real                          1
# frames_cropped_faces_10src      FFD       subu       real        20                16               4            0.80       0.452972       0.066957              real                     1                   real                          1
# frames_cropped_faces_10src      FFD      teggy       real        20                14               6            0.70       0.500652       0.042620              real                     1                   real                          1
# frames_cropped_faces_10src      FFD     thomas       real        20                 2              18            0.10       0.626511       0.077196              fake                     0                   fake                          0
# frames_cropped_faces_10src      FFD      umesh       real        20                19               1            0.95       0.440948       0.033596              real                     1                   real                          1
# frames_cropped_faces_10src      FFD        yad       real        20                10              10            0.50       0.529150       0.024117              fake                     0                   fake                          0

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

import os, time
SAVE_DIR = "/content/drive/MyDrive/FFD results 10 src"
os.makedirs(SAVE_DIR, exist_ok=True)

CSV_PATH = os.path.join(SAVE_DIR, f"ffd_large_table_10src_{time.strftime('%Y%m%d-%H%M%S')}.csv")
df.to_csv(CSV_PATH, index=False)

print("Saved to:", CSV_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved to: /content/drive/MyDrive/FFD results 10 src/ffd_large_table_10src_20251022-110638.csv

# %%
# === Small table from FFD large table `df` (use majority decision) ===
# Columns: dataset, detector, video_name, true_label, correctly_predicted

import pandas as pd
import numpy as np

tl = df["true_label"].astype(str).str.lower()
vp = df["video_pred_by_majority"].astype(str).str.lower()

small_df = df[["dataset","detector","video_name","true_label"]].copy()
small_df["correctly_predicted"] = np.where(vp == tl, "yes", "no")

# show all rows without column breaks
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)
print(small_df.to_string(index=False))
# Out:
#                    dataset detector video_name true_label correctly_predicted
# frames_cropped_faces_10src      FFD       10_1       fake                 yes
# frames_cropped_faces_10src      FFD      10_10       fake                 yes
# frames_cropped_faces_10src      FFD      10_11       fake                 yes
# frames_cropped_faces_10src      FFD      10_12       fake                 yes
# frames_cropped_faces_10src      FFD      10_13       fake                  no
# frames_cropped_faces_10src      FFD      10_14       fake                  no
# frames_cropped_faces_10src      FFD      10_15       fake                  no
# frames_cropped_faces_10src      FFD      10_16       fake                 yes
# frames_cropped_faces_10src      FFD      10_17       fake                  no
# frames_cropped_faces_10src      FFD      10_18       fake                  no
# frames_cropped_faces_10src      FFD      10_19       fake                  no
# frames_cropped_faces_10src      FFD       10_2       fake                  no
# frames_cropped_faces_10src      FFD      10_20       fake                  no
# frames_cropped_faces_10src      FFD      10_21       fake                  no
# frames_cropped_faces_10src      FFD      10_22       fake                 yes
# frames_cropped_faces_10src      FFD      10_23       fake                  no
# frames_cropped_faces_10src      FFD      10_24       fake                 yes
# frames_cropped_faces_10src      FFD      10_25       fake                  no
# frames_cropped_faces_10src      FFD      10_26       fake                  no
# frames_cropped_faces_10src      FFD      10_27       fake                  no
# frames_cropped_faces_10src      FFD      10_28       fake                 yes
# frames_cropped_faces_10src      FFD      10_29       fake                  no
# frames_cropped_faces_10src      FFD       10_3       fake                 yes
# frames_cropped_faces_10src      FFD      10_30       fake                 yes
# frames_cropped_faces_10src      FFD      10_31       fake                 yes
# frames_cropped_faces_10src      FFD      10_32       fake                  no
# frames_cropped_faces_10src      FFD      10_33       fake                  no
# frames_cropped_faces_10src      FFD      10_34       fake                  no
# frames_cropped_faces_10src      FFD      10_35       fake                  no
# frames_cropped_faces_10src      FFD      10_36       fake                  no
# frames_cropped_faces_10src      FFD      10_37       fake                  no
# frames_cropped_faces_10src      FFD      10_38       fake                 yes
# frames_cropped_faces_10src      FFD      10_39       fake                 yes
# frames_cropped_faces_10src      FFD       10_4       fake                 yes
# frames_cropped_faces_10src      FFD      10_40       fake                  no
# frames_cropped_faces_10src      FFD      10_41       fake                 yes
# frames_cropped_faces_10src      FFD      10_42       fake                  no
# frames_cropped_faces_10src      FFD      10_43       fake                  no
# frames_cropped_faces_10src      FFD      10_44       fake                  no
# frames_cropped_faces_10src      FFD      10_45       fake                  no
# frames_cropped_faces_10src      FFD      10_46       fake                  no
# frames_cropped_faces_10src      FFD      10_47       fake                 yes
# frames_cropped_faces_10src      FFD      10_48       fake                  no
# frames_cropped_faces_10src      FFD      10_49       fake                  no
# frames_cropped_faces_10src      FFD       10_5       fake                  no
# frames_cropped_faces_10src      FFD      10_50       fake                  no
# frames_cropped_faces_10src      FFD       10_6       fake                  no
# frames_cropped_faces_10src      FFD       10_7       fake                  no
# frames_cropped_faces_10src      FFD       10_8       fake                 yes
# frames_cropped_faces_10src      FFD       10_9       fake                  no
# frames_cropped_faces_10src      FFD        Ali       real                  no
# frames_cropped_faces_10src      FFD  Elizebeth       real                 yes
# frames_cropped_faces_10src      FFD     Ganesh       real                  no
# frames_cropped_faces_10src      FFD        aji       real                  no
# frames_cropped_faces_10src      FFD      akbar       real                 yes
# frames_cropped_faces_10src      FFD      akhil       real                 yes
# frames_cropped_faces_10src      FFD     akshay       real                 yes
# frames_cropped_faces_10src      FFD       alib       real                  no
# frames_cropped_faces_10src      FFD      ameen       real                  no
# frames_cropped_faces_10src      FFD       ammu       real                 yes
# frames_cropped_faces_10src      FFD     anandu       real                 yes
# frames_cropped_faces_10src      FFD      anish       real                 yes
# frames_cropped_faces_10src      FFD       ansu       real                 yes
# frames_cropped_faces_10src      FFD     arnold       real                  no
# frames_cropped_faces_10src      FFD     assif_       real                  no
# frames_cropped_faces_10src      FFD    baptist       real                 yes
# frames_cropped_faces_10src      FFD   binisha_       real                 yes
# frames_cropped_faces_10src      FFD    chettai       real                 yes
# frames_cropped_faces_10src      FFD      chris       real                  no
# frames_cropped_faces_10src      FFD  christian       real                 yes
# frames_cropped_faces_10src      FFD        col       real                 yes
# frames_cropped_faces_10src      FFD    darwish       real                  no
# frames_cropped_faces_10src      FFD      deeps       real                 yes
# frames_cropped_faces_10src      FFD      denna       real                 yes
# frames_cropped_faces_10src      FFD    fathima       real                 yes
# frames_cropped_faces_10src      FFD     jelvin       real                  no
# frames_cropped_faces_10src      FFD   jennifer       real                 yes
# frames_cropped_faces_10src      FFD      jissa       real                 yes
# frames_cropped_faces_10src      FFD      kevin       real                 yes
# frames_cropped_faces_10src      FFD       lena       real                 yes
# frames_cropped_faces_10src      FFD       liya       real                 yes
# frames_cropped_faces_10src      FFD    liyamom       real                 yes
# frames_cropped_faces_10src      FFD       malu       real                  no
# frames_cropped_faces_10src      FFD      nevin       real                 yes
# frames_cropped_faces_10src      FFD   niranjan       real                 yes
# frames_cropped_faces_10src      FFD    praveen       real                 yes
# frames_cropped_faces_10src      FFD    pushpan       real                 yes
# frames_cropped_faces_10src      FFD      rahul       real                  no
# frames_cropped_faces_10src      FFD       raju       real                 yes
# frames_cropped_faces_10src      FFD      rasee       real                 yes
# frames_cropped_faces_10src      FFD     roshan       real                  no
# frames_cropped_faces_10src      FFD     sachin       real                 yes
# frames_cropped_faces_10src      FFD      salim       real                 yes
# frames_cropped_faces_10src      FFD     seethu       real                  no
# frames_cropped_faces_10src      FFD     shanty       real                 yes
# frames_cropped_faces_10src      FFD       subu       real                 yes
# frames_cropped_faces_10src      FFD      teggy       real                 yes
# frames_cropped_faces_10src      FFD     thomas       real                  no
# frames_cropped_faces_10src      FFD      umesh       real                 yes
# frames_cropped_faces_10src      FFD        yad       real                  no

# %%
# Save the SMALL table (small_df) to the same folder
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

import os, time
SAVE_DIR = "/content/drive/MyDrive/FFD results 10 src"
os.makedirs(SAVE_DIR, exist_ok=True)

out_path = os.path.join(SAVE_DIR, f"ffd_small_table_majority_10src_{time.strftime('%Y%m%d-%H%M%S')}.csv")
small_df.to_csv(out_path, index=False)
print("Saved:", out_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved: /content/drive/MyDrive/FFD results 10 src/ffd_small_table_majority_10src_20251022-111007.csv
